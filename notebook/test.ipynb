# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib_fontja
os.chdir('../')

# %%
# データの読み込み
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
df_sohiki = pd.concat([train['組織図'], test['組織図']], axis=0).reset_index(drop=True)
df_sohiki.to_csv("data/組織図_all.csv", index=False)

# %%
df_sohiki
# Out:
# 0       【経営層】\n├─ 代表取締役社長\n├─ 取締役副社長\n└─ 取締役\n\n【管理本部】...
# 1       経営層\n├─ 経営管理部\n│   ├─ 経営企画室\n│   └─ 財務・人事部\n├─...
# 2       経営層\n├─ 経営企画室\n├─ 管理本部\n│ ├─ 人事部\n│ ├─ 財務部\n│ ...
# 3       【企業組織図】\n\n■ 経営層\n　├─ 経営企画部\n　├─ 自動認識ソリューション事業...
# 4       ────────────────────────────\n【経営層】\n　├─ 代表取締役...
#                               ...
# 1537    ■ 経営層\n　└ 代表取締役社長\n　　　├ 取締役（各事業戦略・経営全般を統括）\n\n...
# 1538    【組織図】\n経営層\n├─ 代表取締役社長\n└─ 執行役員会\n    ├─ 経営企画室...
# 1539    ┌────────────────────────────\n│ 経営層\n│　└─ 代表取...
# 1540    経営層\n├─ DX推進室\n├─ 金融サービス本部\n│ ├─ 預金業務部\n│ ├─ 貸...
# 1541    営業層\n├─ ネットワーク事業部\n│   ├─ 電話システム担当\n│   └─ 運用・...
# Name: 組織図, Length: 1542, dtype: object
